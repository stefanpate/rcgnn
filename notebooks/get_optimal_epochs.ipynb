# %%
import mlflow
import pandas as pd
from pathlib import Path
from hydra import compose, initialize

# %%
with initialize(config_path="../configs/filepaths", version_base=None):
    fps = compose(config_name="base")

# %%
mlflow.set_tracking_uri(fps.tracking_uri)

# %%
filter_split = "params.'data/split_idx' = '0'"

runs = mlflow.search_runs(
    filter_string=filter_split,
)

# %%
runs
# Out:
#                              run_id experiment_id    status  \
# 0  0917682b20b545a59ed98c2d423c56d1             0   RUNNING
# 1  e109a0a7d3564f99bb6688796405dbf1             0   RUNNING
# 2  6bb1753ed0b14a6fb6eddb0d0b3679a5             0  FINISHED
# 3  e54a25eafc65463a95dee11b4a46e4cd             0  FINISHED
# 4  f0d279b0ffed4544bc23a81327e449d0             0  FINISHED
#
#                                         artifact_uri  \
# 0  file:///projects/p30041/spn1560/hiec/results/r...
# 1  file:///projects/p30041/spn1560/hiec/results/r...
# 2  file:///projects/p30041/spn1560/hiec/results/r...
# 3  file:///projects/p30041/spn1560/hiec/results/r...
# 4  file:///projects/p30041/spn1560/hiec/results/r...
#
#                         start_time                         end_time  \
# 0 2025-12-13 21:51:51.302000+00:00                              NaT
# 1 2025-12-13 21:51:51.302000+00:00                              NaT
# 2 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:03:39.122000+00:00
# 3 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:07:59.406000+00:00
# 4 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:03:20.109000+00:00
#
#    metrics.epoch  metrics.val/binary_recall  metrics.val/prc  metrics.val/mcc  \
# 0            2.0                   0.807254         0.718606         0.659214
# 1            2.0                   0.776238         0.662888         0.603651
# 2           24.0                   0.312085         0.257500         0.189659
# 3           24.0                   0.593930         0.671681         0.616076
# 4           24.0                   0.553631         0.517093         0.446415
#
#    ...  params.data/split_bounds  params.model/pos_multiplier  \
# 0  ...         [100, 80, 60, 40]                            1
# 1  ...         [100, 80, 60, 40]                            1
# 2  ...                      None                            1
# 3  ...         [100, 80, 60, 40]                            1
# 4  ...                      None                            1
#
#    params.data/test_percent  params.model/message_passing  params.batch_norm  \
# 0                        20            BondMessagePassing               True
# 1                        20            BondMessagePassing               True
# 2                        20                          None               None
# 3                        20                          None               None
# 4                        20                          None               None
#
#    params.model/vec_len  tags.mlflow.runName tags.mlflow.source.type  \
# 0                  None  treasured-shark-730                   LOCAL
# 1                  None     fearless-dog-559                   LOCAL
# 2                   256      lyrical-elk-168                   LOCAL
# 3                   256  grandiose-steed-931                   LOCAL
# 4                   256    efficient-cub-361                   LOCAL
#
#   tags.mlflow.user              tags.mlflow.source.name
# 0          spn1560  /home/spn1560/hiec/scripts/train.py
# 1          spn1560  /home/spn1560/hiec/scripts/train.py
# 2          spn1560  /home/spn1560/hiec/scripts/train.py
# 3          spn1560  /home/spn1560/hiec/scripts/train.py
# 4          spn1560  /home/spn1560/hiec/scripts/train.py
#
# [5 rows x 54 columns]

# %%
mlflow.artifacts.list_artifacts(run_id="6bb1753ed0b14a6fb6eddb0d0b3679a5")
# Out:
# []

# %%
def get_best_epochs(run_id: str) -> Path:
    dir = Path(fps.tracking_uri.removeprefix("file:///")) / "0" / run_id / "checkpoints"
    return int(str(list(dir.glob('*.ckpt'))[0].stem).split('-')[2])

runs['best_epoch'] = runs['run_id'].apply(get_best_epochs)
runs[['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling', 'best_epoch', 'run_id',]]
# Out:
#   params.model/name params.data/split_strategy params.data/negative_sampling  \
# 0            rc_cxn                      rcmcs                        random
# 1            rc_agg                      rcmcs                        random
# 2             rxnfp     random_reaction_center     alternate_reaction_center
# 3             rxnfp                      rcmcs                        random
# 4             rxnfp            random_reaction     alternate_reaction_center
#
#    best_epoch                            run_id
# 0           2  0917682b20b545a59ed98c2d423c56d1
# 1           2  e109a0a7d3564f99bb6688796405dbf1
# 2          23  6bb1753ed0b14a6fb6eddb0d0b3679a5
# 3          11  e54a25eafc65463a95dee11b4a46e4cd
# 4           8  f0d279b0ffed4544bc23a81327e449d0
