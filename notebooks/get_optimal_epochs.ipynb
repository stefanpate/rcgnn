# %%
import mlflow
import pandas as pd
from pathlib import Path
from hydra import compose, initialize

# %%
with initialize(config_path="../configs/filepaths", version_base=None):
    fps = compose(config_name="base")

def get_best_epochs(run_id: str) -> Path:
    dir = Path(fps.tracking_uri.removeprefix("file:///")) / "0" / run_id / "checkpoints"
    ckpts = list(dir.glob('*.ckpt'))
    val_epochs = [
        (float(ckpt.stem.split('-')[4]), int(ckpt.stem.split('-')[2]))
        for ckpt in ckpts
    ]
    val_epochs = sorted(val_epochs, key=lambda x: x[0], reverse=True)
    if len(val_epochs) == 0:
        return -1
    return val_epochs[0][1]

# %%
mlflow.set_tracking_uri(fps.tracking_uri)

# %%
filter_split = "params.'data/split_idx' = '0'"

runs = mlflow.search_runs(
    filter_string=filter_split,
)

# %%
runs
# Out:
#                              run_id experiment_id    status  \
# 0  7725706057394618bc1c2fad58614627             0  FINISHED
# 1  0917682b20b545a59ed98c2d423c56d1             0  FINISHED
# 2  e109a0a7d3564f99bb6688796405dbf1             0  FINISHED
# 3  6bb1753ed0b14a6fb6eddb0d0b3679a5             0  FINISHED
# 4  e54a25eafc65463a95dee11b4a46e4cd             0  FINISHED
# 5  f0d279b0ffed4544bc23a81327e449d0             0  FINISHED
#
#                                         artifact_uri  \
# 0  file:///projects/p30041/spn1560/hiec/results/r...
# 1  file:///projects/p30041/spn1560/hiec/results/r...
# 2  file:///projects/p30041/spn1560/hiec/results/r...
# 3  file:///projects/p30041/spn1560/hiec/results/r...
# 4  file:///projects/p30041/spn1560/hiec/results/r...
# 5  file:///projects/p30041/spn1560/hiec/results/r...
#
#                         start_time                         end_time  \
# 0 2025-12-14 01:23:51.702000+00:00 2025-12-14 04:35:54.902000+00:00
# 1 2025-12-13 21:51:51.302000+00:00 2025-12-14 01:13:13.305000+00:00
# 2 2025-12-13 21:51:51.302000+00:00 2025-12-14 01:20:24.607000+00:00
# 3 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:03:39.122000+00:00
# 4 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:07:59.406000+00:00
# 5 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:03:20.109000+00:00
#
#    metrics.val_loss  metrics.val/binary_precision  metrics.epoch  \
# 0          0.763859                      0.738416           24.0
# 1          0.681207                      0.778439           24.0
# 2          0.658368                      0.802022           24.0
# 3          0.269219                      0.240004           24.0
# 4          0.645765                      0.714372           24.0
# 5          0.508219                      0.473674           24.0
#
#    metrics.train_loss  ...  params.data/split_idx  params.model/encoder_depth  \
# 0            0.064874  ...                      0                           5
# 1            0.028632  ...                      0                           4
# 2            0.018697  ...                      0                           4
# 3            0.803050  ...                      0                        None
# 4            0.777149  ...                      0                        None
# 5            0.795655  ...                      0                        None
#
#    params.data/toc                            params.data/subdir_patt  \
# 0  v3_folded_pt_ns                 sprhea_v3_folded_pt_ns/rcmcs/3fold
# 1  v3_folded_pt_ns                 sprhea_v3_folded_pt_ns/rcmcs/3fold
# 2  v3_folded_pt_ns                 sprhea_v3_folded_pt_ns/rcmcs/3fold
# 3  v3_folded_pt_ns  sprhea_v3_folded_pt_ns/random_reaction_center_...
# 4  v3_folded_pt_ns                 sprhea_v3_folded_pt_ns/rcmcs/3fold
# 5  v3_folded_pt_ns  sprhea_v3_folded_pt_ns/random_reaction_alterna...
#
#    params.model/name  params.model/vec_len tags.mlflow.user  \
# 0                bom                  None          spn1560
# 1             rc_cxn                  None          spn1560
# 2             rc_agg                  None          spn1560
# 3              rxnfp                   256          spn1560
# 4              rxnfp                   256          spn1560
# 5              rxnfp                   256          spn1560
#
#   tags.mlflow.source.type              tags.mlflow.source.name  \
# 0                   LOCAL  /home/spn1560/hiec/scripts/train.py
# 1                   LOCAL  /home/spn1560/hiec/scripts/train.py
# 2                   LOCAL  /home/spn1560/hiec/scripts/train.py
# 3                   LOCAL  /home/spn1560/hiec/scripts/train.py
# 4                   LOCAL  /home/spn1560/hiec/scripts/train.py
# 5                   LOCAL  /home/spn1560/hiec/scripts/train.py
#
#    tags.mlflow.runName
# 0   judicious-moth-841
# 1  treasured-shark-730
# 2     fearless-dog-559
# 3      lyrical-elk-168
# 4  grandiose-steed-931
# 5    efficient-cub-361
#
# [6 rows x 54 columns]

# %%
mlflow.artifacts.list_artifacts(run_id="6bb1753ed0b14a6fb6eddb0d0b3679a5")
# Out:
# []

# %%
runs['best_epoch'] = runs['run_id'].apply(get_best_epochs)
runs[['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling', 'best_epoch', 'run_id',]]
# Out:
#   params.model/name params.data/split_strategy params.data/negative_sampling  \
# 0               bom                      rcmcs                        random
# 1            rc_cxn                      rcmcs                        random
# 2            rc_agg                      rcmcs                        random
# 3             rxnfp     random_reaction_center     alternate_reaction_center
# 4             rxnfp                      rcmcs                        random
# 5             rxnfp            random_reaction     alternate_reaction_center
#
#    best_epoch                            run_id
# 0           8  7725706057394618bc1c2fad58614627
# 1           8  0917682b20b545a59ed98c2d423c56d1
# 2          11  e109a0a7d3564f99bb6688796405dbf1
# 3          23  6bb1753ed0b14a6fb6eddb0d0b3679a5
# 4          11  e54a25eafc65463a95dee11b4a46e4cd
# 5           8  f0d279b0ffed4544bc23a81327e449d0

# %%
filter_split = "params.'data/split_idx' = '-1'"

test_runs = mlflow.search_runs(
    filter_string=filter_split,
)

test_runs[['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling', 'metrics.val/roc', 'run_id']]
# Out:
#   params.model/name params.data/split_strategy params.data/negative_sampling  \
# 0            rc_agg                      rcmcs                        random
# 1            rc_cxn                      rcmcs                        random
# 2             rxnfp                      rcmcs                        random
# 3             rxnfp     random_reaction_center     alternate_reaction_center
# 4             rxnfp            random_reaction     alternate_reaction_center
#
#    metrics.val/roc                            run_id
# 0         0.951293  1dc77cd293f349c8be87d9184528b7b7
# 1         0.939263  07c2d004e027456eae081e4ac84da733
# 2         0.895310  984013781db24690a081f9ce4cb5e703
# 3         0.654164  81ab29180cc646229ba100fa9e74dfc4
# 4         0.885321  ca1dd48a1eb642848449ce897d943a72

# %%
filter_split = "params.'data/split_idx' = '-2'"

prod_runs = mlflow.search_runs(
    filter_string=filter_split,
)

# %%
prod_runs[['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling', 'metrics.epoch', 'run_id',]]
# Out:
#   params.model/name params.data/split_strategy params.data/negative_sampling  \
# 0            rc_cxn                      rcmcs                        random
# 1            rc_agg                      rcmcs                        random
#
#    metrics.epoch                            run_id
# 0            7.0  550bae7cedce4a20b5669db5c8fb5b98
# 1           10.0  45e615c9594445cb90fe4ae092b3b694
