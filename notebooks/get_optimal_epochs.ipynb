# %%
import mlflow
import pandas as pd
from pathlib import Path
from hydra import compose, initialize

# %%
with initialize(config_path="../configs/filepaths", version_base=None):
    fps = compose(config_name="base")

def get_best_epochs(run_id: str) -> int:
    dir = Path(fps.tracking_uri.removeprefix("file:///")) / "0" / run_id / "checkpoints"
    ckpts = list(dir.glob('*.ckpt'))
    val_epochs = [
        (float(ckpt.stem.split('-')[4]), int(ckpt.stem.split('-')[2]))
        for ckpt in ckpts
    ]
    val_epochs = sorted(val_epochs, key=lambda x: x[0], reverse=True)
    if len(val_epochs) == 0:
        return -1
    return val_epochs[0][1] + 1  # epochs are 0-indexed in filenames

# %%
mlflow.set_tracking_uri(fps.tracking_uri)

# %%
filter_split = "params.'data/split_idx' = '0'"

runs = mlflow.search_runs(
    filter_string=filter_split,
)

# %%
runs
# Out:
#                               run_id experiment_id    status  \
# 0   cfb7fdbeb07a4967affe7f4485957236             0   RUNNING
# 1   8a016e73833f4a9f8e3127ab05a8f448             0   RUNNING
# 2   e3738fe315f64c928c44fe4f8ac6de24             0  FINISHED
# 3   ec68f688ce774c09a5811c38a38b1f8f             0  FINISHED
# 4   0c19be31db744a0e8a0c87905f46c81a             0  FINISHED
# 5   6c60b4f3d0d74c4a9c71ab58d8ca79df             0  FINISHED
# 6   825c6f409237497991112112d2432f48             0  FINISHED
# 7   d651d3368fc8427383ab68266359966f             0   RUNNING
# 8   707754f2458b467d871b76e7cf93b8df             0  FINISHED
# 9   4b7d87b9ffba476e82cadf81c28dd3f8             0  FINISHED
# 10  ac3565b3fe984552922766a57944a54a             0  FINISHED
# 11  103f73d69ff640c99bb8645a2e9146c6             0  FINISHED
# 12  9f917717289f4e9a89564564a38361f3             0  FINISHED
# 13  28abcb5c5573447fa20f212703d5d597             0  FINISHED
# 14  8cff9872dc0441e5a7d1561d75e41149             0  FINISHED
# 15  7725706057394618bc1c2fad58614627             0  FINISHED
# 16  0917682b20b545a59ed98c2d423c56d1             0  FINISHED
# 17  e109a0a7d3564f99bb6688796405dbf1             0  FINISHED
# 18  6bb1753ed0b14a6fb6eddb0d0b3679a5             0  FINISHED
# 19  e54a25eafc65463a95dee11b4a46e4cd             0  FINISHED
# 20  f0d279b0ffed4544bc23a81327e449d0             0  FINISHED
#
#                                          artifact_uri  \
# 0   file:///projects/p30041/spn1560/hiec/results/r...
# 1   file:///projects/p30041/spn1560/hiec/results/r...
# 2   file:///projects/p30041/spn1560/hiec/results/r...
# 3   file:///projects/p30041/spn1560/hiec/results/r...
# 4   file:///projects/p30041/spn1560/hiec/results/r...
# 5   file:///projects/p30041/spn1560/hiec/results/r...
# 6   file:///projects/p30041/spn1560/hiec/results/r...
# 7   file:///projects/p30041/spn1560/hiec/results/r...
# 8   file:///projects/p30041/spn1560/hiec/results/r...
# 9   file:///projects/p30041/spn1560/hiec/results/r...
# 10  file:///projects/p30041/spn1560/hiec/results/r...
# 11  file:///projects/p30041/spn1560/hiec/results/r...
# 12  file:///projects/p30041/spn1560/hiec/results/r...
# 13  file:///projects/p30041/spn1560/hiec/results/r...
# 14  file:///projects/p30041/spn1560/hiec/results/r...
# 15  file:///projects/p30041/spn1560/hiec/results/r...
# 16  file:///projects/p30041/spn1560/hiec/results/r...
# 17  file:///projects/p30041/spn1560/hiec/results/r...
# 18  file:///projects/p30041/spn1560/hiec/results/r...
# 19  file:///projects/p30041/spn1560/hiec/results/r...
# 20  file:///projects/p30041/spn1560/hiec/results/r...
#
#                          start_time                         end_time  \
# 0  2025-12-15 09:54:59.472000+00:00                              NaT
# 1  2025-12-15 04:27:55.540000+00:00                              NaT
# 2  2025-12-15 04:27:55.540000+00:00 2025-12-15 12:29:26.686000+00:00
# 3  2025-12-15 04:27:35.721000+00:00 2025-12-15 09:40:41.798000+00:00
# 4  2025-12-15 04:17:09.981000+00:00 2025-12-15 11:10:55.009000+00:00
# 5  2025-12-15 04:16:53.174000+00:00 2025-12-15 13:26:15.782000+00:00
# 6  2025-12-15 03:54:04.160000+00:00 2025-12-15 11:15:43.168000+00:00
# 7  2025-12-15 03:54:03.281000+00:00                              NaT
# 8  2025-12-15 03:53:38.219000+00:00 2025-12-15 10:33:58.676000+00:00
# 9  2025-12-14 22:45:07.456000+00:00 2025-12-15 02:25:48.744000+00:00
# 10 2025-12-14 18:56:49.156000+00:00 2025-12-14 22:38:22.002000+00:00
# 11 2025-12-14 18:41:35.834000+00:00 2025-12-15 00:10:47.182000+00:00
# 12 2025-12-14 18:41:35.813000+00:00 2025-12-15 00:04:02.849000+00:00
# 13 2025-12-14 18:41:05.894000+00:00 2025-12-14 23:33:31.578000+00:00
# 14 2025-12-14 18:40:54.691000+00:00 2025-12-14 23:00:41.584000+00:00
# 15 2025-12-14 01:23:51.702000+00:00 2025-12-14 04:35:54.902000+00:00
# 16 2025-12-13 21:51:51.302000+00:00 2025-12-14 01:13:13.305000+00:00
# 17 2025-12-13 21:51:51.302000+00:00 2025-12-14 01:20:24.607000+00:00
# 18 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:03:39.122000+00:00
# 19 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:07:59.406000+00:00
# 20 2025-12-13 21:49:12.431000+00:00 2025-12-13 22:03:20.109000+00:00
#
#     metrics.val_loss  metrics.val/accuracy  metrics.epoch  metrics.val/roc  \
# 0           0.681740              0.912826           20.0         0.937603
# 1           0.497429              0.855373           16.0         0.867821
# 2           0.802645              0.956274           24.0         0.972450
# 3           0.640662              0.890778           24.0         0.920642
# 4           0.455349              0.826837           24.0         0.837735
# 5           0.607795              0.911444           24.0         0.910619
# 6           0.655347              0.943353           24.0         0.947453
# 7           0.388875              0.859467           17.0         0.784445
# 8           0.450442              0.882118           24.0         0.800193
# 9           0.526610              0.879614           24.0         0.877561
# 10          0.765038              0.942753           24.0         0.965957
# 11          0.433610              0.833728           24.0         0.879406
# 12          0.584740              0.912174           24.0         0.881378
# 13          0.814402              0.956591           24.0         0.978013
# 14          0.455626              0.814955           24.0         0.895280
# 15          0.763859              0.951883           24.0         0.955133
# 16          0.681207              0.944255           24.0         0.943550
# 17          0.658368              0.943161           24.0         0.952938
# 18          0.269219              0.848222           24.0         0.678366
# 19          0.645765              0.936495           24.0         0.923070
# 20          0.508219              0.884377           24.0         0.866438
#
#     ...  params.warmup_epochs  params.X_d_transform  params.batch_norm  \
# 0   ...                  None                  None               None
# 1   ...                  None                  None               None
# 2   ...                     2                  None               True
# 3   ...                  None                  None               None
# 4   ...                  None                  None               None
# 5   ...                     2                  None               True
# 6   ...                     2                  None               True
# 7   ...                  None                  None               None
# 8   ...                  None                  None               None
# 9   ...                     2                  None               True
# 10  ...                     2                  None               True
# 11  ...                     2                  None               True
# 12  ...                     2                  None               True
# 13  ...                     2                  None               True
# 14  ...                     2                  None               True
# 15  ...                     2                  None               True
# 16  ...                     2                  None               True
# 17  ...                     2                  None               True
# 18  ...                  None                  None               None
# 19  ...                  None                  None               None
# 20  ...                  None                  None               None
#
#     params.init_lr                                     params.metrics  \
# 0             None                                               None
# 1             None                                               None
# 2           0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 3             None                                               None
# 4             None                                               None
# 5           0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 6           0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 7             None                                               None
# 8             None                                               None
# 9           0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 10          0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 11          0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 12          0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 13          0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 14          0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 15          0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 16          0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 17          0.0001  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 18            None                                               None
# 19            None                                               None
# 20            None                                               None
#
#     params.model/radius tags.mlflow.user              tags.mlflow.source.name  \
# 0                  None          spn1560  /home/spn1560/hiec/scripts/train.py
# 1                  None          spn1560  /home/spn1560/hiec/scripts/train.py
# 2                  None          spn1560  /home/spn1560/hiec/scripts/train.py
# 3                     2          spn1560  /home/spn1560/hiec/scripts/train.py
# 4                     2          spn1560  /home/spn1560/hiec/scripts/train.py
# 5                  None          spn1560  /home/spn1560/hiec/scripts/train.py
# 6                  None          spn1560  /home/spn1560/hiec/scripts/train.py
# 7                  None          spn1560  /home/spn1560/hiec/scripts/train.py
# 8                     2          spn1560  /home/spn1560/hiec/scripts/train.py
# 9                  None          spn1560  /home/spn1560/hiec/scripts/train.py
# 10                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 11                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 12                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 13                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 14                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 15                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 16                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 17                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 18                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 19                 None          spn1560  /home/spn1560/hiec/scripts/train.py
# 20                 None          spn1560  /home/spn1560/hiec/scripts/train.py
#
#    tags.mlflow.source.type   tags.mlflow.runName
# 0                    LOCAL       bouncy-lark-884
# 1                    LOCAL    resilient-fish-941
# 2                    LOCAL    unleashed-colt-871
# 3                    LOCAL       dapper-calf-261
# 4                    LOCAL           big-croc-84
# 5                    LOCAL     grandiose-hen-412
# 6                    LOCAL  rebellious-finch-358
# 7                    LOCAL         calm-sponge-3
# 8                    LOCAL  industrious-loon-772
# 9                    LOCAL       silent-croc-665
# 10                   LOCAL        suave-kite-155
# 11                   LOCAL    languid-sponge-830
# 12                   LOCAL    mercurial-gull-385
# 13                   LOCAL     resilient-bat-591
# 14                   LOCAL       clumsy-kite-249
# 15                   LOCAL    judicious-moth-841
# 16                   LOCAL   treasured-shark-730
# 17                   LOCAL      fearless-dog-559
# 18                   LOCAL       lyrical-elk-168
# 19                   LOCAL   grandiose-steed-931
# 20                   LOCAL     efficient-cub-361
#
# [21 rows x 55 columns]

# %%
runs['best_epoch'] = runs['run_id'].apply(get_best_epochs)
runs[['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling', 'best_epoch', 'run_id',]].sort_values(
    by=['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling']
)
# Out:
#    params.model/name params.data/split_strategy params.data/negative_sampling  \
# 9                bom            random_reaction     alternate_reaction_center
# 14               bom     random_reaction_center     alternate_reaction_center
# 15               bom                      rcmcs                        random
# 2                cgr            random_reaction     alternate_reaction_center
# 5                cgr     random_reaction_center     alternate_reaction_center
# 6                cgr                      rcmcs                        random
# 0               drfp            random_reaction     alternate_reaction_center
# 1               drfp     random_reaction_center     alternate_reaction_center
# 7               drfp                      rcmcs                        random
# 3                mfp            random_reaction     alternate_reaction_center
# 4                mfp     random_reaction_center     alternate_reaction_center
# 8                mfp                      rcmcs                        random
# 13            rc_agg            random_reaction     alternate_reaction_center
# 11            rc_agg     random_reaction_center     alternate_reaction_center
# 17            rc_agg                      rcmcs                        random
# 10            rc_cxn            random_reaction     alternate_reaction_center
# 12            rc_cxn     random_reaction_center     alternate_reaction_center
# 16            rc_cxn                      rcmcs                        random
# 20             rxnfp            random_reaction     alternate_reaction_center
# 18             rxnfp     random_reaction_center     alternate_reaction_center
# 19             rxnfp                      rcmcs                        random
#
#     best_epoch                            run_id
# 9           24  4b7d87b9ffba476e82cadf81c28dd3f8
# 14          24  8cff9872dc0441e5a7d1561d75e41149
# 15           9  7725706057394618bc1c2fad58614627
# 2           15  e3738fe315f64c928c44fe4f8ac6de24
# 5           24  6c60b4f3d0d74c4a9c71ab58d8ca79df
# 6           12  825c6f409237497991112112d2432f48
# 0           21  cfb7fdbeb07a4967affe7f4485957236
# 1            9  8a016e73833f4a9f8e3127ab05a8f448
# 7           15  d651d3368fc8427383ab68266359966f
# 3           24  ec68f688ce774c09a5811c38a38b1f8f
# 4            3  0c19be31db744a0e8a0c87905f46c81a
# 8           12  707754f2458b467d871b76e7cf93b8df
# 13          21  28abcb5c5573447fa20f212703d5d597
# 11           6  103f73d69ff640c99bb8645a2e9146c6
# 17          12  e109a0a7d3564f99bb6688796405dbf1
# 10          24  ac3565b3fe984552922766a57944a54a
# 12          12  9f917717289f4e9a89564564a38361f3
# 16           9  0917682b20b545a59ed98c2d423c56d1
# 20           9  f0d279b0ffed4544bc23a81327e449d0
# 18          24  6bb1753ed0b14a6fb6eddb0d0b3679a5
# 19          12  e54a25eafc65463a95dee11b4a46e4cd

# %%
filter_split = "params.'data/split_idx' = '-1'"

test_runs = mlflow.search_runs(
    filter_string=filter_split,
)

test_runs[['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling', 'metrics.val/roc', 'run_id']].sort_values(
    by=['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling']
)
# Out:
#    params.model/name params.data/split_strategy params.data/negative_sampling  \
# 6                bom            random_reaction     alternate_reaction_center
# 10               bom     random_reaction_center     alternate_reaction_center
# 14               bom                      rcmcs                        random
# 0                cgr            random_reaction     alternate_reaction_center
# 1                cgr     random_reaction_center     alternate_reaction_center
# 2                cgr                      rcmcs                        random
# 3                mfp            random_reaction     alternate_reaction_center
# 4                mfp     random_reaction_center     alternate_reaction_center
# 5                mfp                      rcmcs                        random
# 8             rc_agg            random_reaction     alternate_reaction_center
# 9             rc_agg     random_reaction_center     alternate_reaction_center
# 13            rc_agg                      rcmcs                        random
# 7             rc_cxn            random_reaction     alternate_reaction_center
# 11            rc_cxn     random_reaction_center     alternate_reaction_center
# 12            rc_cxn                      rcmcs                        random
#
#     metrics.val/roc                            run_id
# 6          0.941901  55c062d229394c4f82828814300c0f2b
# 10         0.729101  35d782fa639e4035b08d5c74a4f002f9
# 14         0.908215  d1a3cc3f1d36488e8222efda0d595914
# 0          0.982500  120f090f4b3e471a965979401b3271ae
# 1          0.807885  34cda1e3f64a4b18a98894ed0e86be86
# 2          0.914909  e627a08cec3c47e18b4fd9f1ade6b9fe
# 3          0.852761  7e836b6654ac4b9aba81fe692b059c5d
# 4          0.679670  ec2310e5872f47de8b9c81d1edce26b9
# 5          0.755406  04cc886dade64a68a84b151ddd92cef2
# 8          0.985613  1d6c62f5f2d44b3fa82851639fb44ead
# 9          0.835046  30ed98a93bb149f6b7b6c08779e95915
# 13         0.938557  da9ed201898a451a8a822cf1a30ec30b
# 7          0.974725  56c0235555af4e4c98dd6293c824cc2f
# 11         0.817493  874ef317e1b7403c9be3665c3c301d90
# 12         0.939463  af29e2f62cf34bf2824dc8c72e086da5

# %%
filter_split = "params.'data/split_idx' = '-2'"

prod_runs = mlflow.search_runs(
    filter_string=filter_split,
)

# %%
prod_runs[['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling', 'metrics.epoch', 'run_id',]].sort_values(
    by=['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling']
)
# Out:
#    params.model/name params.data/split_strategy params.data/negative_sampling  \
# 6                bom     random_reaction_center     alternate_reaction_center
# 12               bom                      rcmcs                        random
# 0                cgr     random_reaction_center     alternate_reaction_center
# 1                cgr                      rcmcs                        random
# 2                mfp     random_reaction_center     alternate_reaction_center
# 3                mfp                      rcmcs                        random
# 4             rc_agg     random_reaction_center     alternate_reaction_center
# 13            rc_agg                      rcmcs                        random
# 5             rc_cxn     random_reaction_center     alternate_reaction_center
# 14            rc_cxn                      rcmcs                        random
# 9              rxnfp            random_reaction     alternate_reaction_center
# 8              rxnfp     random_reaction_center     alternate_reaction_center
# 10             rxnfp     random_reaction_center     alternate_reaction_center
# 7              rxnfp                      rcmcs                        random
# 11             rxnfp                      rcmcs                        random
#
#     metrics.epoch                            run_id
# 6            23.0  fafcf359d8864d1a8d012d65eb4f350d
# 12            8.0  2fcb812a06c841d282d378d9f99e64c9
# 0            14.0  25964e2b2fcb4ee1aa6f5487866209bd
# 1            11.0  4c7872263bba4bd2952057c3146c7c9f
# 2            23.0  b736cf547f5b46a0b8eb0308bddcabbd
# 3            11.0  baa4374b85ca4deaa6df54cdc14617b7
# 4             5.0  9226ba678bcd42fbb95b44979deeabff
# 13           11.0  1fbaa827a8384e8da2fadaaa945fce13
# 5            11.0  99fb3dad48464fd8a2af365b5fd57621
# 14            8.0  722de30540f6401d8d7fd12e8c2d0b4a
# 9             8.0  e0058aa0fae9479385f6d75dd2aa19fa
# 8            23.0  b37763cf52bd4949acbc6c0b0423a054
# 10           23.0  bafd3f63b98f4028a9cc85c444503801
# 7            11.0  2ae3adca4b534b6cb25872db6788bbad
# 11           11.0  ddf2e1bd0bd64c5186b53a95d79d46a4

# %%
for _, row in runs.iterrows():
    print(row['run_id'])

for _, row in test_runs.iterrows():
    print(row['run_id'])
# Out:
# cfb7fdbeb07a4967affe7f4485957236
# 8a016e73833f4a9f8e3127ab05a8f448
# e3738fe315f64c928c44fe4f8ac6de24
# ec68f688ce774c09a5811c38a38b1f8f
# 0c19be31db744a0e8a0c87905f46c81a
# 6c60b4f3d0d74c4a9c71ab58d8ca79df
# 825c6f409237497991112112d2432f48
# d651d3368fc8427383ab68266359966f
# 707754f2458b467d871b76e7cf93b8df
# 4b7d87b9ffba476e82cadf81c28dd3f8
# ac3565b3fe984552922766a57944a54a
# 103f73d69ff640c99bb8645a2e9146c6
# 9f917717289f4e9a89564564a38361f3
# 28abcb5c5573447fa20f212703d5d597
# 8cff9872dc0441e5a7d1561d75e41149
# 7725706057394618bc1c2fad58614627
# 0917682b20b545a59ed98c2d423c56d1
# e109a0a7d3564f99bb6688796405dbf1
# 6bb1753ed0b14a6fb6eddb0d0b3679a5
# e54a25eafc65463a95dee11b4a46e4cd
# f0d279b0ffed4544bc23a81327e449d0
# 120f090f4b3e471a965979401b3271ae
# 34cda1e3f64a4b18a98894ed0e86be86
# e627a08cec3c47e18b4fd9f1ade6b9fe
# 7e836b6654ac4b9aba81fe692b059c5d
# ec2310e5872f47de8b9c81d1edce26b9
# 04cc886dade64a68a84b151ddd92cef2
# 55c062d229394c4f82828814300c0f2b
# 56c0235555af4e4c98dd6293c824cc2f
# 1d6c62f5f2d44b3fa82851639fb44ead
# 30ed98a93bb149f6b7b6c08779e95915
# 35d782fa639e4035b08d5c74a4f002f9
# 874ef317e1b7403c9be3665c3c301d90
# af29e2f62cf34bf2824dc8c72e086da5
# da9ed201898a451a8a822cf1a30ec30b
# d1a3cc3f1d36488e8222efda0d595914

# %%
join_cols = ['params.model/name', 'params.data/split_strategy', 'params.data/negative_sampling']
in_out = pd.merge(runs, test_runs, how='inner', on=join_cols, suffixes=('_in', '_out'))
in_out.head()
# Out:
#                           run_id_in experiment_id_in status_in  \
# 0  e3738fe315f64c928c44fe4f8ac6de24                0  FINISHED
# 1  ec68f688ce774c09a5811c38a38b1f8f                0  FINISHED
# 2  0c19be31db744a0e8a0c87905f46c81a                0  FINISHED
# 3  6c60b4f3d0d74c4a9c71ab58d8ca79df                0  FINISHED
# 4  825c6f409237497991112112d2432f48                0  FINISHED
#
#                                      artifact_uri_in  \
# 0  file:///projects/p30041/spn1560/hiec/results/r...
# 1  file:///projects/p30041/spn1560/hiec/results/r...
# 2  file:///projects/p30041/spn1560/hiec/results/r...
# 3  file:///projects/p30041/spn1560/hiec/results/r...
# 4  file:///projects/p30041/spn1560/hiec/results/r...
#
#                      start_time_in                      end_time_in  \
# 0 2025-12-15 04:27:55.540000+00:00 2025-12-15 12:29:26.686000+00:00
# 1 2025-12-15 04:27:35.721000+00:00 2025-12-15 09:40:41.798000+00:00
# 2 2025-12-15 04:17:09.981000+00:00 2025-12-15 11:10:55.009000+00:00
# 3 2025-12-15 04:16:53.174000+00:00 2025-12-15 13:26:15.782000+00:00
# 4 2025-12-15 03:54:04.160000+00:00 2025-12-15 11:15:43.168000+00:00
#
#    metrics.val_loss_in  metrics.val/accuracy_in  metrics.epoch_in  \
# 0             0.802645                 0.956274              24.0
# 1             0.640662                 0.890778              24.0
# 2             0.455349                 0.826837              24.0
# 3             0.607795                 0.911444              24.0
# 4             0.655347                 0.943353              24.0
#
#    metrics.val/roc_in  ...  params.data/seed_out  params.batch_norm_out  \
# 0            0.972450  ...                  1234                   True
# 1            0.920642  ...                  1234                   None
# 2            0.837735  ...                  1234                   None
# 3            0.910619  ...                  1234                   True
# 4            0.947453  ...                  1234                   True
#
#    params.data/n_splits_out  \
# 0                         3
# 1                         3
# 2                         3
# 3                         3
# 4                         3
#
#                                   params.metrics_out  \
# 0  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 1                                               None
# 2                                               None
# 3  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
# 4  [BinaryF1Metric(task_weights=[[1.0]]), BinaryP...
#
#    params.model/vec_len_out  params.model/radius_out tags.mlflow.user_out  \
# 0                      None                     None              spn1560
# 1                      2048                        2              spn1560
# 2                      2048                        2              spn1560
# 3                      None                     None              spn1560
# 4                      None                     None              spn1560
#
#            tags.mlflow.source.name_out tags.mlflow.source.type_out  \
# 0  /home/spn1560/hiec/scripts/train.py                       LOCAL
# 1  /home/spn1560/hiec/scripts/train.py                       LOCAL
# 2  /home/spn1560/hiec/scripts/train.py                       LOCAL
# 3  /home/spn1560/hiec/scripts/train.py                       LOCAL
# 4  /home/spn1560/hiec/scripts/train.py                       LOCAL
#
#   tags.mlflow.runName_out
# 0     incongruous-ram-908
# 1        wistful-horse-72
# 2      welcoming-shad-999
# 3        fearless-hare-64
# 4           caring-fox-87
#
# [5 rows x 108 columns]

# %%
for _, row in in_out.iterrows():
    print(f"{row['run_id_in']}: {row['run_id_out']}")
# Out:
# e3738fe315f64c928c44fe4f8ac6de24: 120f090f4b3e471a965979401b3271ae
# ec68f688ce774c09a5811c38a38b1f8f: 7e836b6654ac4b9aba81fe692b059c5d
# 0c19be31db744a0e8a0c87905f46c81a: ec2310e5872f47de8b9c81d1edce26b9
# 6c60b4f3d0d74c4a9c71ab58d8ca79df: 34cda1e3f64a4b18a98894ed0e86be86
# 825c6f409237497991112112d2432f48: e627a08cec3c47e18b4fd9f1ade6b9fe
# 707754f2458b467d871b76e7cf93b8df: 04cc886dade64a68a84b151ddd92cef2
# 4b7d87b9ffba476e82cadf81c28dd3f8: 55c062d229394c4f82828814300c0f2b
# ac3565b3fe984552922766a57944a54a: 56c0235555af4e4c98dd6293c824cc2f
# 103f73d69ff640c99bb8645a2e9146c6: 30ed98a93bb149f6b7b6c08779e95915
# 9f917717289f4e9a89564564a38361f3: 874ef317e1b7403c9be3665c3c301d90
# 28abcb5c5573447fa20f212703d5d597: 1d6c62f5f2d44b3fa82851639fb44ead
# 8cff9872dc0441e5a7d1561d75e41149: 35d782fa639e4035b08d5c74a4f002f9
# 7725706057394618bc1c2fad58614627: d1a3cc3f1d36488e8222efda0d595914
# 0917682b20b545a59ed98c2d423c56d1: af29e2f62cf34bf2824dc8c72e086da5
# e109a0a7d3564f99bb6688796405dbf1: da9ed201898a451a8a822cf1a30ec30b
