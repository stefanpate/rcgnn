# %%
import mlflow
from mlflow.tracking import MlflowClient

# Set the tracking URI
mlflow.set_tracking_uri("file:///home/stef/quest_data/hiec/results/runs")

experiment = mlflow.get_experiment_by_name("encoder_dim")
mlflow.search_runs(experiment.experiment_id)

# # Initialize the client
# client = MlflowClient()

# # List all runs
# experiment_ids = [exp.experiment_id for exp in client.list_experiments()]
# runs = [client.search_runs(experiment_id) for experiment_id in experiment_ids]

# # Flatten the list of runs
# all_runs = [run for sublist in runs for run in sublist]

# # Display the runs
# for run in all_runs:
#     print(f"Run ID: {run.info.run_id}, Status: {run.info.status}, Start Time: {run.info.start_time}")
# Out:
#                              run_id       experiment_id    status  \
# 0  4fb9c9fb5ce8435197f840861db652cb  390957942392378165  FINISHED
# 1  237e8cfaa8614585b65290713cc8d8c1  390957942392378165  FINISHED
# 2  a3b69ec737fa46f1b1919ae6b564e943  390957942392378165  FINISHED
# 3  8dc10033da3847a48f2ff636f2018ce3  390957942392378165  FINISHED
# 4  0c1b2e47effe4d34a70a24752c2fc8f5  390957942392378165  FINISHED
#
#                                         artifact_uri  \
# 0  file:///projects/p30041/spn1560/hiec/results/r...
# 1  file:///projects/p30041/spn1560/hiec/results/r...
# 2  file:///projects/p30041/spn1560/hiec/results/r...
# 3  file:///projects/p30041/spn1560/hiec/results/r...
# 4  file:///projects/p30041/spn1560/hiec/results/r...
#
#                         start_time                         end_time  \
# 0 2025-01-06 04:32:26.499000+00:00 2025-01-06 08:31:23.527000+00:00
# 1 2025-01-06 04:30:13.007000+00:00 2025-01-06 07:30:28.136000+00:00
# ...
